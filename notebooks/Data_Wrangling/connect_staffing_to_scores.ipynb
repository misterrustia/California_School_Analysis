# %%
import pandas as pd
import numpy as np 
import dabl
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfs = pd.read_csv('../data/cleaned_labeled_2021-SB_math_ela_scores.csv' )
dfs['District Name'] = dfs['District Name'].astype(str).str.lower()
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28698 entries, 0 to 28697
# Data columns (total 38 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   28698 non-null  int64
#  1   County Code                                  28698 non-null  int64
#  2   District Code                                28698 non-null  int64
#  3   School Code                                  28698 non-null  int64
#  4   Test Year_x                                  28698 non-null  int64
#  5   Student Group ID                             28698 non-null  int64
#  6   Total Tested at Reporting Level              27490 non-null  float64
#  7   Total Tested with Scores at Reporting Level  27473 non-null  float64
#  8   Grade                                        28698 non-null  int64
#  9   Test ID                                      0 non-null      float64
#  10  Students Enrolled                            27037 non-null  float64
#  11  Students Tested                              25806 non-null  float64
#  12  Mean Scale Score                             16468 non-null  float64
#  13  Percentage Standard Exceeded                 22939 non-null  float64
#  14  Percentage Standard Met                      22939 non-null  float64
#  15  Percentage Standard Met and Above            22939 non-null  float64
#  16  Percentage Standard Nearly Met               22939 non-null  float64
#  17  Percentage Standard Not Met                  22939 non-null  float64
#  18  Students with Scores                         25787 non-null  float64
#  19  Area 1 Percentage Above Standard             18571 non-null  float64
#  20  Area 1 Percentage Near Standard              18571 non-null  float64
#  21  Area 1 Percentage Below Standard             18571 non-null  float64
#  22  Area 2 Percentage Above Standard             18571 non-null  float64
#  23  Area 2 Percentage Near Standard              18571 non-null  float64
#  24  Area 2 Percentage Below Standard             18571 non-null  float64
#  25  Area 3 Percentage Above Standard             18571 non-null  float64
#  26  Area 3 Percentage Near Standard              18571 non-null  float64
#  27  Area 3 Percentage Below Standard             18571 non-null  float64
#  28  Area 4 Percentage Above Standard             18571 non-null  float64
#  29  Area 4 Percentage Near Standard              18571 non-null  float64
#  30  Area 4 Percentage Below Standard             18571 non-null  float64
#  31  Type ID_x                                    28698 non-null  int64
#  32  Test Year_y                                  28698 non-null  int64
#  33  Type ID_y                                    28698 non-null  int64
#  34  County Name                                  28698 non-null  object
#  35  District Name                                28698 non-null  object
#  36  School Name                                  28698 non-null  object
#  37  Zip Code                                     28698 non-null  float64
# dtypes: float64(25), int64(10), object(3)
# memory usage: 8.3+ MB

# %%
fte = pd.read_excel('2021_cal_school_FTE_numbers.xlsx',header=6)
fte.rename(columns={'Agency Name':'District Name'},inplace=True)
fte['District Name'] = fte['District Name'].astype(str).str.lower()
fte.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2137 entries, 0 to 2136
# Data columns (total 8 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   District Name                                                2137 non-null   object
#  1   State Name [District] Latest available year                  2130 non-null   object
#  2   State Name [District] 2020-21                                2130 non-null   object
#  3   Agency ID - NCES Assigned [District] Latest available year   2130 non-null   float64
#  4   County Name [District] 2020-21                               2130 non-null   object
#  5   Total Students, All Grades (Excludes AE) [District] 2020-21  2130 non-null   object
#  6   Full-Time Equivalent (FTE) Teachers [District] 2020-21       2130 non-null   object
#  7   Pupil/Teacher Ratio [District] 2020-21                       2130 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 133.7+ KB

# %%
lowers[:5]
# Out:
# 0                                 abc unified
# 1            academia avance charter district
# 2                   academia moderna district
# 3    academy for academic excellence district
# 4              academy of media arts district
# Name: District Name, dtype: object

# %%
## join teacher info and scores 

comdf = dfs.merge(fte, how='inner', on=['District Name'],indicator=True)

# %%
comdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24435 entries, 0 to 24434
# Data columns (total 46 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Unnamed: 0                                                   24435 non-null  int64
#  1   County Code                                                  24435 non-null  int64
#  2   District Code                                                24435 non-null  int64
#  3   School Code                                                  24435 non-null  int64
#  4   Test Year_x                                                  24435 non-null  int64
#  5   Student Group ID                                             24435 non-null  int64
#  6   Total Tested at Reporting Level                              23274 non-null  float64
#  7   Total Tested with Scores at Reporting Level                  23261 non-null  float64
#  8   Grade                                                        24435 non-null  int64
#  9   Test ID                                                      0 non-null      float64
#  10  Students Enrolled                                            22853 non-null  float64
#  11  Students Tested                                              21798 non-null  float64
#  12  Mean Scale Score                                             13679 non-null  float64
#  13  Percentage Standard Exceeded                                 19344 non-null  float64
#  14  Percentage Standard Met                                      19344 non-null  float64
#  15  Percentage Standard Met and Above                            19344 non-null  float64
#  16  Percentage Standard Nearly Met                               19344 non-null  float64
#  17  Percentage Standard Not Met                                  19344 non-null  float64
#  18  Students with Scores                                         21785 non-null  float64
#  19  Area 1 Percentage Above Standard                             15989 non-null  float64
#  20  Area 1 Percentage Near Standard                              15989 non-null  float64
#  21  Area 1 Percentage Below Standard                             15989 non-null  float64
#  22  Area 2 Percentage Above Standard                             15989 non-null  float64
#  23  Area 2 Percentage Near Standard                              15989 non-null  float64
#  24  Area 2 Percentage Below Standard                             15989 non-null  float64
#  25  Area 3 Percentage Above Standard                             15989 non-null  float64
#  26  Area 3 Percentage Near Standard                              15989 non-null  float64
#  27  Area 3 Percentage Below Standard                             15989 non-null  float64
#  28  Area 4 Percentage Above Standard                             15989 non-null  float64
#  29  Area 4 Percentage Near Standard                              15989 non-null  float64
#  30  Area 4 Percentage Below Standard                             15989 non-null  float64
#  31  Type ID_x                                                    24435 non-null  int64
#  32  Test Year_y                                                  24435 non-null  int64
#  33  Type ID_y                                                    24435 non-null  int64
#  34  County Name                                                  24435 non-null  object
#  35  District Name                                                24435 non-null  object
#  36  School Name                                                  24435 non-null  object
#  37  Zip Code                                                     24435 non-null  float64
#  38  State Name [District] Latest available year                  24435 non-null  object
#  39  State Name [District] 2020-21                                24435 non-null  object
#  40  Agency ID - NCES Assigned [District] Latest available year   24435 non-null  float64
#  41  County Name [District] 2020-21                               24435 non-null  object
#  42  Total Students, All Grades (Excludes AE) [District] 2020-21  24435 non-null  object
#  43  Full-Time Equivalent (FTE) Teachers [District] 2020-21       24435 non-null  object
#  44  Pupil/Teacher Ratio [District] 2020-21                       24435 non-null  object
#  45  _merge                                                       24435 non-null  category
# dtypes: category(1), float64(26), int64(10), object(9)
# memory usage: 8.6+ MB

# %%
comdf[[ 'County Name', 'District Name',
       'School Name', 'Zip Code',
       'Total Students, All Grades (Excludes AE) [District] 2020-21',
       'Full-Time Equivalent (FTE) Teachers [District] 2020-21',
       'Pupil/Teacher Ratio [District] 2020-21','Total Tested with Scores at Reporting Level', 'Grade', 'Test ID',
       'Students Enrolled', 'Students Tested', 'Mean Scale Score', '_merge']].sample(4)
# Out:
#       County Name                         District Name         School Name  \
# 91        Alameda                 castro valley unified  Stanton Elementary
# 8615       Madera                 golden valley unified      Ranchos Middle
# 17333   San Mateo           south san francisco unified      El Camino High
# 11721   Riverside  riverside county office of education      Come Back Kids
#
#        Zip Code Total Students, All Grades (Excludes AE) [District] 2020-21  \
# 91      94546.0                                               9203
# 8615    93636.0                                               2089
# 17333   94080.0                                               8182
# 11721   92501.0                                               1444
#
#       Full-Time Equivalent (FTE) Teachers [District] 2020-21  \
# 91                                                395.49
# 8615                                               96.14
# 17333                                              396.2
# 11721                                             128.02
#
#       Pupil/Teacher Ratio [District] 2020-21  \
# 91                                     23.27
# 8615                                   21.73
# 17333                                  20.65
# 11721                                  11.28
#
#        Total Tested with Scores at Reporting Level  Grade  Test ID  \
# 91                                           223.0      4      NaN
# 8615                                         336.0      8      NaN
# 17333                                        147.0     13      NaN
# 11721                                        142.0     13      NaN
#
#        Students Enrolled  Students Tested  Mean Scale Score _merge
# 91                  79.0             75.0            2455.9   both
# 8615               173.0            164.0            2513.2   both
# 17333              309.0            148.0               NaN   both
# 11721              166.0            143.0               NaN   both

# %%
comdf[comdf['School Name']=='River Glen'][[ 'County Name', 'District Name',
       'School Name', 'Zip Code',
       'Total Students, All Grades (Excludes AE) [District] 2020-21',
       'Full-Time Equivalent (FTE) Teachers [District] 2020-21',
       'Pupil/Teacher Ratio [District] 2020-21','Total Tested with Scores at Reporting Level', 'Grade', 'Test ID',
       'Students Enrolled', 'Students Tested', 'Mean Scale Score', '_merge']]
# Out:
#        County Name     District Name School Name  Zip Code  \
# 18432  Santa Clara  san jose unified  River Glen   95125.0
# 18433  Santa Clara  san jose unified  River Glen   95125.0
# 18434  Santa Clara  san jose unified  River Glen   95125.0
# 18435  Santa Clara  san jose unified  River Glen   95125.0
# 18436  Santa Clara  san jose unified  River Glen   95125.0
# 18437  Santa Clara  san jose unified  River Glen   95125.0
# 18438  Santa Clara  san jose unified  River Glen   95125.0
# 18439  Santa Clara  san jose unified  River Glen   95125.0
# 18440  Santa Clara  san jose unified  River Glen   95125.0
# 18441  Santa Clara  san jose unified  River Glen   95125.0
# 18442  Santa Clara  san jose unified  River Glen   95125.0
# 18443  Santa Clara  san jose unified  River Glen   95125.0
# 18444  Santa Clara  san jose unified  River Glen   95125.0
# 18445  Santa Clara  san jose unified  River Glen   95125.0
#
#       Total Students, All Grades (Excludes AE) [District] 2020-21  \
# 18432                                              27430
# 18433                                              27430
# 18434                                              27430
# 18435                                              27430
# 18436                                              27430
# 18437                                              27430
# 18438                                              27430
# 18439                                              27430
# 18440                                              27430
# 18441                                              27430
# 18442                                              27430
# 18443                                              27430
# 18444                                              27430
# 18445                                              27430
#
#       Full-Time Equivalent (FTE) Teachers [District] 2020-21  \
# 18432                                            1266.08
# 18433                                            1266.08
# 18434                                            1266.08
# 18435                                            1266.08
# 18436                                            1266.08
# 18437                                            1266.08
# 18438                                            1266.08
# 18439                                            1266.08
# 18440                                            1266.08
# 18441                                            1266.08
# 18442                                            1266.08
# 18443                                            1266.08
# 18444                                            1266.08
# 18445                                            1266.08
#
#       Pupil/Teacher Ratio [District] 2020-21  \
# 18432                                  21.67
# 18433                                  21.67
# 18434                                  21.67
# 18435                                  21.67
# 18436                                  21.67
# 18437                                  21.67
# 18438                                  21.67
# 18439                                  21.67
# 18440                                  21.67
# 18441                                  21.67
# 18442                                  21.67
# 18443                                  21.67
# 18444                                  21.67
# 18445                                  21.67
#
#        Total Tested with Scores at Reporting Level  Grade  Test ID  \
# 18432                                        271.0      3      NaN
# 18433                                        271.0      4      NaN
# 18434                                        271.0      5      NaN
# 18435                                        271.0      6      NaN
# 18436                                        271.0      7      NaN
# 18437                                        271.0      8      NaN
# 18438                                        271.0     13      NaN
# 18439                                        273.0      3      NaN
# 18440                                        273.0      4      NaN
# 18441                                        273.0      5      NaN
# 18442                                        273.0      6      NaN
# 18443                                        273.0      7      NaN
# 18444                                        273.0      8      NaN
# 18445                                        273.0     13      NaN
#
#        Students Enrolled  Students Tested  Mean Scale Score _merge
# 18432               57.0             51.0            2372.2   both
# 18433               59.0             56.0            2424.8   both
# 18434               57.0             55.0            2486.9   both
# 18435               49.0             45.0            2505.5   both
# 18436               37.0             35.0            2579.3   both
# 18437               40.0             31.0            2574.4   both
# 18438              299.0            273.0               NaN   both
# 18439               57.0             51.0            2390.2   both
# 18440               59.0             56.0            2416.4   both
# 18441               57.0             55.0            2451.7   both
# 18442               49.0             45.0            2454.1   both
# 18443               37.0             35.0            2541.6   both
# 18444               40.0             31.0            2519.5   both
# 18445              299.0            273.0               NaN   both

# %%
## ok fte has some all caps and and dfs does not , need to convert all to lower to match, good find!

# %%
cols =  ['Total Students, All Grades (Excludes AE) [District] 2020-21',
       'Full-Time Equivalent (FTE) Teachers [District] 2020-21',
       'Pupil/Teacher Ratio [District] 2020-21']

for i in cols:
    comdf[i] = comdf[i].apply(pd.to_numeric,errors='coerce')
#     c[i] = c[i].astype(float)

# %%
comdf[[ 'Total Students, All Grades (Excludes AE) [District] 2020-21',
       'Full-Time Equivalent (FTE) Teachers [District] 2020-21',
       'Pupil/Teacher Ratio [District] 2020-21']].sample(4)
# Out:
#        Total Students, All Grades (Excludes AE) [District] 2020-21  \
# 8785                                              1434.0
# 8736                                              1860.0
# 17748                                            15663.0
# 23371                                             5718.0
#
#        Full-Time Equivalent (FTE) Teachers [District] 2020-21  \
# 8785                                               67.42
# 8736                                               91.00
# 17748                                             686.09
# 23371                                             247.23
#
#        Pupil/Teacher Ratio [District] 2020-21
# 8785                                    21.27
# 8736                                    20.44
# 17748                                   22.83
# 23371                                   23.13

# %%
comdf.to_csv('../data/fte_cleaned_labels.csv')

# %%
dabl.plot(comdf[[ 
       'Total Tested with Scores at Reporting Level', 'Grade',
       'Students Enrolled', 'Students Tested', 'Mean Scale Score',
       'Percentage Standard Exceeded', 'Percentage Standard Met',
       'Percentage Standard Met and Above', 'Percentage Standard Nearly Met',
       'Percentage Standard Not Met', 'Students with Scores', 'County Name', 'District Name',
       'School Name',
       'County Name [District] 2020-21',
       'Total Students, All Grades (Excludes AE) [District] 2020-21',
       'Full-Time Equivalent (FTE) Teachers [District] 2020-21',
       'Pupil/Teacher Ratio [District] 2020-21']], target_col='Mean Scale Score')
# Out:
# Target looks like regression
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/supervised.py:58: UserWarning: Missing values in target_col have been removed for regression
#   warn("Missing values in target_col have been removed for regression",
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:632: UserWarning: Dropped 6 outliers in column Students Enrolled.
#   warn("Dropped {} outliers in column {}.".format(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:632: UserWarning: Dropped 3 outliers in column Percentage Standard Nearly Met.
#   warn("Dropped {} outliers in column {}.".format(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:632: UserWarning: Dropped 12 outliers in column Pupil/Teacher Ratio [District] 2020-21.
#   warn("Dropped {} outliers in column {}.".format(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/supervised.py:130: UserWarning: Missing values in target_col have been removed for regression
#   warn("Missing values in target_col have been removed for regression",
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [array([[<AxesSubplot:title={'center':'F=1.34E+04'}, xlabel='Percentage Standa...', ylabel='Mean Scale Score'>,
#          <AxesSubplot:title={'center':'F=1.28E+04'}, xlabel='Percentage Standa...'>,
#          <AxesSubplot:title={'center':'F=1.00E+04'}, xlabel='Grade'>,
#          <AxesSubplot:title={'center':'F=9.24E+03'}, xlabel='Percentage Standa...'>,
#          <AxesSubplot:title={'center':'F=5.15E+03'}, xlabel='Percentage Standa...'>],
#         [<AxesSubplot:title={'center':'F=3.38E+03'}, xlabel='Students Enrolled', ylabel='Mean Scale Score'>,
#          <AxesSubplot:title={'center':'F=2.33E+03'}, xlabel='Students with Scores'>,
#          <AxesSubplot:title={'center':'F=2.31E+03'}, xlabel='Students Tested'>,
#          <AxesSubplot:title={'center':'F=2.61E+02'}, xlabel='Total Tested with...'>,
#          <AxesSubplot:title={'center':'F=2.25E+02'}, xlabel='Total Students, A...'>],
#         [<AxesSubplot:title={'center':'F=2.19E+02'}, xlabel='Full-Time Equival...', ylabel='Mean Scale Score'>,
#          <AxesSubplot:title={'center':'F=2.00E+02'}, xlabel='Percentage Standa...'>,
#          <AxesSubplot:title={'center':'F=1.49E+00'}, xlabel='Pupil/Teacher Rat...'>,
#          <AxesSubplot:>, <AxesSubplot:>]], dtype=object),
#  array([[<AxesSubplot:title={'center':'F=9.27E-02'}, xlabel='Mean Scale Score', ylabel='County Name'>,
#          <AxesSubplot:title={'center':'F=5.91E-02'}, xlabel='Mean Scale Score', ylabel='County Name [Dist...'>]],
#        dtype=object)]

# %%
heat = comdf[[ 
       'Total Tested with Scores at Reporting Level', 'Grade',
       'Students Enrolled', 'Students Tested', 'Mean Scale Score',
       'Percentage Standard Exceeded', 'Percentage Standard Met',
       'Percentage Standard Met and Above', 'Percentage Standard Nearly Met',
       'Percentage Standard Not Met', 'Students with Scores', 'County Name', 'District Name',
       'School Name','Zip Code',
       'County Name [District] 2020-21',
       'Total Students, All Grades (Excludes AE) [District] 2020-21',
       'Full-Time Equivalent (FTE) Teachers [District] 2020-21',
       'Pupil/Teacher Ratio [District] 2020-21']]

# %%
fig ,ax = plt.subplots(figsize=(12,12))

sns.heatmap(heat.corr(),annot=True, ax=ax )
# Out:
# <AxesSubplot:>
