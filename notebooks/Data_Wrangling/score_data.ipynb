# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import dabl

# %% [markdown]
# Data wrangling
#
# 1 import packages
# 2 load data
# 3 join data on school code
#
# 4 observe nulls and remove - found "*  " so need to convert data types after dealing with special characters

# %%
dfs = pd.read_csv('sb_ca2021_1_csv_v2.txt' ,delimiter = "^")
dfs.drop('Filler',axis=1,inplace=True)
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100251 entries, 0 to 100250
# Data columns (total 32 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   County Code                                  100251 non-null  int64
#  1   District Code                                100251 non-null  int64
#  2   School Code                                  100251 non-null  int64
#  3   Test Year                                    100251 non-null  int64
#  4   Student Group ID                             100251 non-null  int64
#  5   Test Type                                    100251 non-null  object
#  6   Total Tested at Reporting Level              100251 non-null  object
#  7   Total Tested with Scores at Reporting Level  100251 non-null  object
#  8   Grade                                        100251 non-null  int64
#  9   Test ID                                      100251 non-null  int64
#  10  Students Enrolled                            100251 non-null  object
#  11  Students Tested                              100251 non-null  object
#  12  Mean Scale Score                             28764 non-null   object
#  13  Percentage Standard Exceeded                 37938 non-null   object
#  14  Percentage Standard Met                      37938 non-null   object
#  15  Percentage Standard Met and Above            37938 non-null   object
#  16  Percentage Standard Nearly Met               37938 non-null   object
#  17  Percentage Standard Not Met                  37938 non-null   object
#  18  Students with Scores                         100251 non-null  object
#  19  Area 1 Percentage Above Standard             37938 non-null   object
#  20  Area 1 Percentage Near Standard              37938 non-null   object
#  21  Area 1 Percentage Below Standard             37938 non-null   object
#  22  Area 2 Percentage Above Standard             37938 non-null   object
#  23  Area 2 Percentage Near Standard              37938 non-null   object
#  24  Area 2 Percentage Below Standard             37938 non-null   object
#  25  Area 3 Percentage Above Standard             37938 non-null   object
#  26  Area 3 Percentage Near Standard              37938 non-null   object
#  27  Area 3 Percentage Below Standard             37938 non-null   object
#  28  Area 4 Percentage Above Standard             37938 non-null   object
#  29  Area 4 Percentage Near Standard              37938 non-null   object
#  30  Area 4 Percentage Below Standard             37938 non-null   object
#  31  Type ID                                      100251 non-null  int64
# dtypes: int64(8), object(24)
# memory usage: 24.5+ MB

# %%
dfs['Test ID'].unique()
# Out:
# array([1, 2])

# %%
# convert test types to name 
dfs['Test ID'] = dfs['Test ID'].map({1:'English Language Arts/Literacy',2:'Mathematics'})
dfs['Test ID'].unique()
# Out:
# array(['English Language Arts/Literacy', 'Mathematics'], dtype=object)

# %%
## unclear on this column atm 

dfs['Type ID'].value_counts()
# Out:
# 7     73529
# 6     13504
# 9      9154
# 10     3122
# 5       926
# 4        16
# Name: Type ID, dtype: int64

# %%
dfs.head()
# Out:
#    County Code  District Code  School Code  Test Year  Student Group ID  \
# 0            0              0            0       2021                 1
# 1            0              0            0       2021                 1
# 2            0              0            0       2021                 1
# 3            0              0            0       2021                 1
# 4            0              0            0       2021                 1
#
#   Test Type Total Tested at Reporting Level  \
# 0         B                          743626
# 1         B                          743626
# 2         B                          743626
# 3         B                          743626
# 4         B                          743626
#
#   Total Tested with Scores at Reporting Level  Grade  \
# 0                                      736192      3
# 1                                      736192      4
# 2                                      736192      5
# 3                                      736192      6
# 4                                      736192      7
#
#                           Test ID  ... Area 2 Percentage Above Standard  \
# 0  English Language Arts/Literacy  ...                            12.98
# 1  English Language Arts/Literacy  ...                            13.48
# 2  English Language Arts/Literacy  ...                            20.30
# 3  English Language Arts/Literacy  ...                            16.27
# 4  English Language Arts/Literacy  ...                            21.89
#
#   Area 2 Percentage Near Standard Area 2 Percentage Below Standard  \
# 0                           50.72                            36.30
# 1                           53.53                            32.99
# 2                           47.31                            32.39
# 3                           49.77                            33.96
# 4                           52.05                            26.06
#
#   Area 3 Percentage Above Standard Area 3 Percentage Near Standard  \
# 0                            10.49                           71.78
# 1                            11.20                           71.90
# 2                            12.46                           72.32
# 3                            13.76                           70.17
# 4                            12.07                           73.94
#
#   Area 3 Percentage Below Standard Area 4 Percentage Above Standard  \
# 0                            17.72                            16.57
# 1                            16.89                            15.35
# 2                            15.23                            18.43
# 3                            16.07                            19.33
# 4                            13.99                            23.26
#
#   Area 4 Percentage Near Standard Area 4 Percentage Below Standard Type ID
# 0                           61.65                            21.77       4
# 1                           66.49                            18.16       4
# 2                           59.19                            22.38       4
# 3                           63.41                            17.26       4
# 4                           60.55                            16.19       4
#
# [5 rows x 32 columns]

# %%
dfs[dfs['School Code']==0][['County Code','District Code','School Code']].nunique()
# Out:
# County Code       59
# District Code    992
# School Code        1
# dtype: int64

# %%
dfs[dfs['School Code']==112607].T
# Out:
#                                                                          40  \
# County Code                                                               1
# District Code                                                         10017
# School Code                                                          112607
# Test Year                                                              2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                         108
# Total Tested with Scores at Reporting Level                             106
# Grade                                                                     6
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                        21
# Students Tested                                                          20
# Mean Scale Score                                                     2438.1
# Percentage Standard Exceeded                                           5.26
# Percentage Standard Met                                               21.05
# Percentage Standard Met and Above                                     26.32
# Percentage Standard Nearly Met                                        15.79
# Percentage Standard Not Met                                           57.89
# Students with Scores                                                     19
# Area 1 Percentage Above Standard                                          *
# Area 1 Percentage Near Standard                                           *
# Area 1 Percentage Below Standard                                          *
# Area 2 Percentage Above Standard                                          *
# Area 2 Percentage Near Standard                                           *
# Area 2 Percentage Below Standard                                          *
# Area 3 Percentage Above Standard                                          *
# Area 3 Percentage Near Standard                                           *
# Area 3 Percentage Below Standard                                          *
# Area 4 Percentage Above Standard                                          *
# Area 4 Percentage Near Standard                                           *
# Area 4 Percentage Below Standard                                          *
# Type ID                                                                   9
#
#                                                                          41  \
# County Code                                                               1
# District Code                                                         10017
# School Code                                                          112607
# Test Year                                                              2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                         108
# Total Tested with Scores at Reporting Level                             106
# Grade                                                                     7
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                        38
# Students Tested                                                          26
# Mean Scale Score                                                     2506.3
# Percentage Standard Exceeded                                           3.85
# Percentage Standard Met                                               42.31
# Percentage Standard Met and Above                                     46.15
# Percentage Standard Nearly Met                                        15.38
# Percentage Standard Not Met                                           38.46
# Students with Scores                                                     26
# Area 1 Percentage Above Standard                                          *
# Area 1 Percentage Near Standard                                           *
# Area 1 Percentage Below Standard                                          *
# Area 2 Percentage Above Standard                                          *
# Area 2 Percentage Near Standard                                           *
# Area 2 Percentage Below Standard                                          *
# Area 3 Percentage Above Standard                                          *
# Area 3 Percentage Near Standard                                           *
# Area 3 Percentage Below Standard                                          *
# Area 4 Percentage Above Standard                                          *
# Area 4 Percentage Near Standard                                           *
# Area 4 Percentage Below Standard                                          *
# Type ID                                                                   9
#
#                                                                          42  \
# County Code                                                               1
# District Code                                                         10017
# School Code                                                          112607
# Test Year                                                              2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                         108
# Total Tested with Scores at Reporting Level                             106
# Grade                                                                    11
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                        94
# Students Tested                                                          62
# Mean Scale Score                                                     2579.7
# Percentage Standard Exceeded                                          13.11
# Percentage Standard Met                                               39.34
# Percentage Standard Met and Above                                     52.46
# Percentage Standard Nearly Met                                        27.87
# Percentage Standard Not Met                                           19.67
# Students with Scores                                                     61
# Area 1 Percentage Above Standard                                      23.33
# Area 1 Percentage Near Standard                                       58.33
# Area 1 Percentage Below Standard                                      18.33
# Area 2 Percentage Above Standard                                      10.00
# Area 2 Percentage Near Standard                                       60.00
# Area 2 Percentage Below Standard                                      30.00
# Area 3 Percentage Above Standard                                      16.39
# Area 3 Percentage Near Standard                                       75.41
# Area 3 Percentage Below Standard                                       8.20
# Area 4 Percentage Above Standard                                      26.23
# Area 4 Percentage Near Standard                                       65.57
# Area 4 Percentage Below Standard                                       8.20
# Type ID                                                                   9
#
#                                                                          43  \
# County Code                                                               1
# District Code                                                         10017
# School Code                                                          112607
# Test Year                                                              2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                         108
# Total Tested with Scores at Reporting Level                             106
# Grade                                                                    13
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                       153
# Students Tested                                                         108
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                           9.43
# Percentage Standard Met                                               36.79
# Percentage Standard Met and Above                                     46.23
# Percentage Standard Nearly Met                                        22.64
# Percentage Standard Not Met                                           31.13
# Students with Scores                                                    106
# Area 1 Percentage Above Standard                                      14.29
# Area 1 Percentage Near Standard                                       57.14
# Area 1 Percentage Below Standard                                      28.57
# Area 2 Percentage Above Standard                                      10.48
# Area 2 Percentage Near Standard                                       51.43
# Area 2 Percentage Below Standard                                      38.10
# Area 3 Percentage Above Standard                                      12.26
# Area 3 Percentage Near Standard                                       71.70
# Area 3 Percentage Below Standard                                      16.04
# Area 4 Percentage Above Standard                                      19.81
# Area 4 Percentage Near Standard                                       62.26
# Area 4 Percentage Below Standard                                      17.92
# Type ID                                                                   9
#
#                                                       44           45  \
# County Code                                            1            1
# District Code                                      10017        10017
# School Code                                       112607       112607
# Test Year                                           2021         2021
# Student Group ID                                       1            1
# Test Type                                              B            B
# Total Tested at Reporting Level                      111          111
# Total Tested with Scores at Reporting Level          105          105
# Grade                                                  6            7
# Test ID                                      Mathematics  Mathematics
# Students Enrolled                                     21           38
# Students Tested                                       20           28
# Mean Scale Score                                  2387.8       2478.7
# Percentage Standard Exceeded                        5.00         3.85
# Percentage Standard Met                             0.00        15.38
# Percentage Standard Met and Above                   5.00        19.23
# Percentage Standard Nearly Met                     20.00        38.46
# Percentage Standard Not Met                        75.00        42.31
# Students with Scores                                  20           26
# Area 1 Percentage Above Standard                       *            *
# Area 1 Percentage Near Standard                        *            *
# Area 1 Percentage Below Standard                       *            *
# Area 2 Percentage Above Standard                       *            *
# Area 2 Percentage Near Standard                        *            *
# Area 2 Percentage Below Standard                       *            *
# Area 3 Percentage Above Standard                       *            *
# Area 3 Percentage Near Standard                        *            *
# Area 3 Percentage Below Standard                       *            *
# Area 4 Percentage Above Standard                       *            *
# Area 4 Percentage Near Standard                        *            *
# Area 4 Percentage Below Standard                       *            *
# Type ID                                                9            9
#
#                                                       46           47
# County Code                                            1            1
# District Code                                      10017        10017
# School Code                                       112607       112607
# Test Year                                           2021         2021
# Student Group ID                                       1            1
# Test Type                                              B            B
# Total Tested at Reporting Level                      111          111
# Total Tested with Scores at Reporting Level          105          105
# Grade                                                 11           13
# Test ID                                      Mathematics  Mathematics
# Students Enrolled                                     94          153
# Students Tested                                       63          111
# Mean Scale Score                                  2533.3          NaN
# Percentage Standard Exceeded                        6.78         5.71
# Percentage Standard Met                            15.25        12.38
# Percentage Standard Met and Above                  22.03        18.10
# Percentage Standard Nearly Met                     18.64        23.81
# Percentage Standard Not Met                        59.32        58.10
# Students with Scores                                  59          105
# Area 1 Percentage Above Standard                   11.86         8.74
# Area 1 Percentage Near Standard                    25.42        32.04
# Area 1 Percentage Below Standard                   62.71        59.22
# Area 2 Percentage Above Standard                   11.86         7.62
# Area 2 Percentage Near Standard                    57.63        50.48
# Area 2 Percentage Below Standard                   30.51        41.90
# Area 3 Percentage Above Standard                    8.47         8.57
# Area 3 Percentage Near Standard                    74.58        65.71
# Area 3 Percentage Below Standard                   16.95        25.71
# Area 4 Percentage Above Standard                    0.00         0.00
# Area 4 Percentage Near Standard                     0.00         0.00
# Area 4 Percentage Below Standard                    0.00         0.00
# Type ID                                                9            9

# %% [markdown]
# ## looks like if the there are not alot of students in a group the scores are with held. only had enough scores for 11th grade, if this is a trend I can use just those students instead of the slower schools

# %%
dfs[dfs['School Code']==130401].T
# Out:
#                                                                          76  \
# County Code                                                               1
# District Code                                                         10017
# School Code                                                          130401
# Test Year                                                              2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                           0
# Total Tested with Scores at Reporting Level                               0
# Grade                                                                     7
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                         *
# Students Tested                                                           0
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                            NaN
# Percentage Standard Met                                                 NaN
# Percentage Standard Met and Above                                       NaN
# Percentage Standard Nearly Met                                          NaN
# Percentage Standard Not Met                                             NaN
# Students with Scores                                                      0
# Area 1 Percentage Above Standard                                        NaN
# Area 1 Percentage Near Standard                                         NaN
# Area 1 Percentage Below Standard                                        NaN
# Area 2 Percentage Above Standard                                        NaN
# Area 2 Percentage Near Standard                                         NaN
# Area 2 Percentage Below Standard                                        NaN
# Area 3 Percentage Above Standard                                        NaN
# Area 3 Percentage Near Standard                                         NaN
# Area 3 Percentage Below Standard                                        NaN
# Area 4 Percentage Above Standard                                        NaN
# Area 4 Percentage Near Standard                                         NaN
# Area 4 Percentage Below Standard                                        NaN
# Type ID                                                                   7
#
#                                                                          77  \
# County Code                                                               1
# District Code                                                         10017
# School Code                                                          130401
# Test Year                                                              2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                           0
# Total Tested with Scores at Reporting Level                               0
# Grade                                                                     8
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                         *
# Students Tested                                                           0
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                            NaN
# Percentage Standard Met                                                 NaN
# Percentage Standard Met and Above                                       NaN
# Percentage Standard Nearly Met                                          NaN
# Percentage Standard Not Met                                             NaN
# Students with Scores                                                      0
# Area 1 Percentage Above Standard                                        NaN
# Area 1 Percentage Near Standard                                         NaN
# Area 1 Percentage Below Standard                                        NaN
# Area 2 Percentage Above Standard                                        NaN
# Area 2 Percentage Near Standard                                         NaN
# Area 2 Percentage Below Standard                                        NaN
# Area 3 Percentage Above Standard                                        NaN
# Area 3 Percentage Near Standard                                         NaN
# Area 3 Percentage Below Standard                                        NaN
# Area 4 Percentage Above Standard                                        NaN
# Area 4 Percentage Near Standard                                         NaN
# Area 4 Percentage Below Standard                                        NaN
# Type ID                                                                   7
#
#                                                                          78  \
# County Code                                                               1
# District Code                                                         10017
# School Code                                                          130401
# Test Year                                                              2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                           0
# Total Tested with Scores at Reporting Level                               0
# Grade                                                                    11
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                        10
# Students Tested                                                           0
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                            NaN
# Percentage Standard Met                                                 NaN
# Percentage Standard Met and Above                                       NaN
# Percentage Standard Nearly Met                                          NaN
# Percentage Standard Not Met                                             NaN
# Students with Scores                                                      0
# Area 1 Percentage Above Standard                                        NaN
# Area 1 Percentage Near Standard                                         NaN
# Area 1 Percentage Below Standard                                        NaN
# Area 2 Percentage Above Standard                                        NaN
# Area 2 Percentage Near Standard                                         NaN
# Area 2 Percentage Below Standard                                        NaN
# Area 3 Percentage Above Standard                                        NaN
# Area 3 Percentage Near Standard                                         NaN
# Area 3 Percentage Below Standard                                        NaN
# Area 4 Percentage Above Standard                                        NaN
# Area 4 Percentage Near Standard                                         NaN
# Area 4 Percentage Below Standard                                        NaN
# Type ID                                                                   7
#
#                                                                          79  \
# County Code                                                               1
# District Code                                                         10017
# School Code                                                          130401
# Test Year                                                              2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                           0
# Total Tested with Scores at Reporting Level                               0
# Grade                                                                    13
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                        13
# Students Tested                                                           0
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                            NaN
# Percentage Standard Met                                                 NaN
# Percentage Standard Met and Above                                       NaN
# Percentage Standard Nearly Met                                          NaN
# Percentage Standard Not Met                                             NaN
# Students with Scores                                                      0
# Area 1 Percentage Above Standard                                        NaN
# Area 1 Percentage Near Standard                                         NaN
# Area 1 Percentage Below Standard                                        NaN
# Area 2 Percentage Above Standard                                        NaN
# Area 2 Percentage Near Standard                                         NaN
# Area 2 Percentage Below Standard                                        NaN
# Area 3 Percentage Above Standard                                        NaN
# Area 3 Percentage Near Standard                                         NaN
# Area 3 Percentage Below Standard                                        NaN
# Area 4 Percentage Above Standard                                        NaN
# Area 4 Percentage Near Standard                                         NaN
# Area 4 Percentage Below Standard                                        NaN
# Type ID                                                                   7
#
#                                                       80           81  \
# County Code                                            1            1
# District Code                                      10017        10017
# School Code                                       130401       130401
# Test Year                                           2021         2021
# Student Group ID                                       1            1
# Test Type                                              B            B
# Total Tested at Reporting Level                        0            0
# Total Tested with Scores at Reporting Level            0            0
# Grade                                                  7            8
# Test ID                                      Mathematics  Mathematics
# Students Enrolled                                      *            *
# Students Tested                                        0            0
# Mean Scale Score                                     NaN          NaN
# Percentage Standard Exceeded                         NaN          NaN
# Percentage Standard Met                              NaN          NaN
# Percentage Standard Met and Above                    NaN          NaN
# Percentage Standard Nearly Met                       NaN          NaN
# Percentage Standard Not Met                          NaN          NaN
# Students with Scores                                   0            0
# Area 1 Percentage Above Standard                     NaN          NaN
# Area 1 Percentage Near Standard                      NaN          NaN
# Area 1 Percentage Below Standard                     NaN          NaN
# Area 2 Percentage Above Standard                     NaN          NaN
# Area 2 Percentage Near Standard                      NaN          NaN
# Area 2 Percentage Below Standard                     NaN          NaN
# Area 3 Percentage Above Standard                     NaN          NaN
# Area 3 Percentage Near Standard                      NaN          NaN
# Area 3 Percentage Below Standard                     NaN          NaN
# Area 4 Percentage Above Standard                     NaN          NaN
# Area 4 Percentage Near Standard                      NaN          NaN
# Area 4 Percentage Below Standard                     NaN          NaN
# Type ID                                                7            7
#
#                                                       82           83
# County Code                                            1            1
# District Code                                      10017        10017
# School Code                                       130401       130401
# Test Year                                           2021         2021
# Student Group ID                                       1            1
# Test Type                                              B            B
# Total Tested at Reporting Level                        0            0
# Total Tested with Scores at Reporting Level            0            0
# Grade                                                 11           13
# Test ID                                      Mathematics  Mathematics
# Students Enrolled                                     10           13
# Students Tested                                        0            0
# Mean Scale Score                                     NaN          NaN
# Percentage Standard Exceeded                         NaN          NaN
# Percentage Standard Met                              NaN          NaN
# Percentage Standard Met and Above                    NaN          NaN
# Percentage Standard Nearly Met                       NaN          NaN
# Percentage Standard Not Met                          NaN          NaN
# Students with Scores                                   0            0
# Area 1 Percentage Above Standard                     NaN          NaN
# Area 1 Percentage Near Standard                      NaN          NaN
# Area 1 Percentage Below Standard                     NaN          NaN
# Area 2 Percentage Above Standard                     NaN          NaN
# Area 2 Percentage Near Standard                      NaN          NaN
# Area 2 Percentage Below Standard                     NaN          NaN
# Area 3 Percentage Above Standard                     NaN          NaN
# Area 3 Percentage Near Standard                      NaN          NaN
# Area 3 Percentage Below Standard                     NaN          NaN
# Area 4 Percentage Above Standard                     NaN          NaN
# Area 4 Percentage Near Standard                      NaN          NaN
# Area 4 Percentage Below Standard                     NaN          NaN
# Type ID                                                7            7

# %%
dfs[dfs['Students Tested']=='0']
# Out:
# Empty DataFrame
# Columns: [County Code, District Code, School Code, Test Year, Student Group ID, Test Type, Total Tested at Reporting Level, Total Tested with Scores at Reporting Level, Grade, Test ID, Students Enrolled, Students Tested, Mean Scale Score, Percentage Standard Exceeded, Percentage Standard Met, Percentage Standard Met and Above, Percentage Standard Nearly Met, Percentage Standard Not Met, Students with Scores, Area 1 Percentage Above Standard, Area 1 Percentage Near Standard, Area 1 Percentage Below Standard, Area 2 Percentage Above Standard, Area 2 Percentage Near Standard, Area 2 Percentage Below Standard, Area 3 Percentage Above Standard, Area 3 Percentage Near Standard, Area 3 Percentage Below Standard, Area 4 Percentage Above Standard, Area 4 Percentage Near Standard, Area 4 Percentage Below Standard, Type ID]
# Index: []
#
# [0 rows x 32 columns]

# %%
## Can drop all School where no students were tested

# %%
print(len(dfs))
drops = dfs[dfs['Students Tested']=='0'].index
len(drops)
dfs= dfs.drop(drops)
print(len(dfs))

#check nulls gone 
dfs[dfs['Students Tested']=='0']
# Out:
# 100251
# 100251
# 37977
# Empty DataFrame
# Columns: [County Code, District Code, School Code, Test Year, Student Group ID, Test Type, Total Tested at Reporting Level, Total Tested with Scores at Reporting Level, Grade, Test ID, Students Enrolled, Students Tested, Mean Scale Score, Percentage Standard Exceeded, Percentage Standard Met, Percentage Standard Met and Above, Percentage Standard Nearly Met, Percentage Standard Not Met, Students with Scores, Area 1 Percentage Above Standard, Area 1 Percentage Near Standard, Area 1 Percentage Below Standard, Area 2 Percentage Above Standard, Area 2 Percentage Near Standard, Area 2 Percentage Below Standard, Area 3 Percentage Above Standard, Area 3 Percentage Near Standard, Area 3 Percentage Below Standard, Area 4 Percentage Above Standard, Area 4 Percentage Near Standard, Area 4 Percentage Below Standard, Type ID]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# # just under 38 k schools left after removing no students tested

# %%
dfs.duplicated(subset=['School Code','District Code','County Code']).sum()
# Out:
# 33310

# %%
dfs.duplicated(subset=['Grade','Test ID','School Code','District Code']).sum()
# Out:
# 918

# %%
dfs.duplicated(subset=['Grade','Test ID','School Code','District Code','County Code']).sum()
# Out:
# 0

# %% [markdown]
# To get unique columns need to use 5 columns listed above

# %%
dfs[dfs['District Code']==10017]
# Out:
#      County Code  District Code  School Code  Test Year  Student Group ID  \
# 32             1          10017            0       2021                 1
# 33             1          10017            0       2021                 1
# 34             1          10017            0       2021                 1
# 35             1          10017            0       2021                 1
# 36             1          10017            0       2021                 1
# ..           ...            ...          ...        ...               ...
# 141            1          10017      6002000       2021                 1
# 142            1          10017      6002000       2021                 1
# 143            1          10017      6002000       2021                 1
# 144            1          10017      6002000       2021                 1
# 145            1          10017      6002000       2021                 1
#
#     Test Type Total Tested at Reporting Level  \
# 32          B                               5
# 33          B                               5
# 34          B                               5
# 35          B                               5
# 36          B                               5
# ..        ...                             ...
# 141         B                               0
# 142         B                               0
# 143         B                               0
# 144         B                               0
# 145         B                               0
#
#     Total Tested with Scores at Reporting Level  Grade  Test ID  ...  \
# 32                                            5      7        1  ...
# 33                                            5      8        1  ...
# 34                                            5     11        1  ...
# 35                                            5     13        1  ...
# 36                                            5      7        2  ...
# ..                                          ...    ...      ...  ...
# 141                                           0      5        2  ...
# 142                                           0      6        2  ...
# 143                                           0      7        2  ...
# 144                                           0      8        2  ...
# 145                                           0     13        2  ...
#
#     Area 2 Percentage Above Standard Area 2 Percentage Near Standard  \
# 32                               NaN                             NaN
# 33                               NaN                             NaN
# 34                                 *                               *
# 35                                 *                               *
# 36                               NaN                             NaN
# ..                               ...                             ...
# 141                              NaN                             NaN
# 142                              NaN                             NaN
# 143                              NaN                             NaN
# 144                              NaN                             NaN
# 145                              NaN                             NaN
#
#     Area 2 Percentage Below Standard Area 3 Percentage Above Standard  \
# 32                               NaN                              NaN
# 33                               NaN                              NaN
# 34                                 *                                *
# 35                                 *                                *
# 36                               NaN                              NaN
# ..                               ...                              ...
# 141                              NaN                              NaN
# 142                              NaN                              NaN
# 143                              NaN                              NaN
# 144                              NaN                              NaN
# 145                              NaN                              NaN
#
#     Area 3 Percentage Near Standard Area 3 Percentage Below Standard  \
# 32                              NaN                              NaN
# 33                              NaN                              NaN
# 34                                *                                *
# 35                                *                                *
# 36                              NaN                              NaN
# ..                              ...                              ...
# 141                             NaN                              NaN
# 142                             NaN                              NaN
# 143                             NaN                              NaN
# 144                             NaN                              NaN
# 145                             NaN                              NaN
#
#     Area 4 Percentage Above Standard Area 4 Percentage Near Standard  \
# 32                               NaN                             NaN
# 33                               NaN                             NaN
# 34                                 *                               *
# 35                                 *                               *
# 36                               NaN                             NaN
# ..                               ...                             ...
# 141                              NaN                             NaN
# 142                              NaN                             NaN
# 143                              NaN                             NaN
# 144                              NaN                             NaN
# 145                              NaN                             NaN
#
#     Area 4 Percentage Below Standard Type ID
# 32                               NaN       6
# 33                               NaN       6
# 34                                 *       6
# 35                                 *       6
# 36                               NaN       6
# ..                               ...     ...
# 141                              NaN       9
# 142                              NaN       9
# 143                              NaN       9
# 144                              NaN       9
# 145                              NaN       9
#
# [114 rows x 32 columns]

# %%
entities = pd.read_csv('sb_ca2021entities_csv.txt',delimiter='^')
entities.drop('Filler',axis=1,inplace=True)
entities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11149 entries, 0 to 11148
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   County Code    11149 non-null  int64
#  1   District Code  11149 non-null  int64
#  2   School Code    11149 non-null  int64
#  3   Test Year      11149 non-null  int64
#  4   Type ID        11149 non-null  int64
#  5   County Name    11149 non-null  object
#  6   District Name  11090 non-null  object
#  7   School Name    10099 non-null  object
#  8   Zip Code       10099 non-null  float64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 784.0+ KB

# %%
entities['School Code'].nunique()
# Out:
# 10100

# %%
df = dfs.merge(entities,how='inner',on=['School Code','District Code','County Code'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37977 entries, 0 to 37976
# Data columns (total 38 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   County Code                                  37977 non-null  int64
#  1   District Code                                37977 non-null  int64
#  2   School Code                                  37977 non-null  int64
#  3   Test Year_x                                  37977 non-null  int64
#  4   Student Group ID                             37977 non-null  int64
#  5   Test Type                                    37977 non-null  object
#  6   Total Tested at Reporting Level              37977 non-null  object
#  7   Total Tested with Scores at Reporting Level  37977 non-null  object
#  8   Grade                                        37977 non-null  int64
#  9   Test ID                                      37977 non-null  object
#  10  Students Enrolled                            37977 non-null  object
#  11  Students Tested                              37977 non-null  object
#  12  Mean Scale Score                             28764 non-null  object
#  13  Percentage Standard Exceeded                 37938 non-null  object
#  14  Percentage Standard Met                      37938 non-null  object
#  15  Percentage Standard Met and Above            37938 non-null  object
#  16  Percentage Standard Nearly Met               37938 non-null  object
#  17  Percentage Standard Not Met                  37938 non-null  object
#  18  Students with Scores                         37977 non-null  object
#  19  Area 1 Percentage Above Standard             37938 non-null  object
#  20  Area 1 Percentage Near Standard              37938 non-null  object
#  21  Area 1 Percentage Below Standard             37938 non-null  object
#  22  Area 2 Percentage Above Standard             37938 non-null  object
#  23  Area 2 Percentage Near Standard              37938 non-null  object
#  24  Area 2 Percentage Below Standard             37938 non-null  object
#  25  Area 3 Percentage Above Standard             37938 non-null  object
#  26  Area 3 Percentage Near Standard              37938 non-null  object
#  27  Area 3 Percentage Below Standard             37938 non-null  object
#  28  Area 4 Percentage Above Standard             37938 non-null  object
#  29  Area 4 Percentage Near Standard              37938 non-null  object
#  30  Area 4 Percentage Below Standard             37938 non-null  object
#  31  Type ID_x                                    37977 non-null  int64
#  32  Test Year_y                                  37977 non-null  int64
#  33  Type ID_y                                    37977 non-null  int64
#  34  County Name                                  37977 non-null  object
#  35  District Name                                37043 non-null  object
#  36  School Name                                  28729 non-null  object
#  37  Zip Code                                     28729 non-null  float64
# dtypes: float64(1), int64(9), object(28)
# memory usage: 11.3+ MB

# %%
# there are 58 counties in california

# %%
df[['County Code', 'District Code','School Code']].nunique()
# Out:
# County Code        59
# District Code     786
# School Code      3858
# dtype: int64

# %%
## check nulls 
m = pd.DataFrame([df.isnull().sum(),100*df.isnull().mean()])
m = m.T
m.columns=['count', '%']
m = m.sort_values(by='count',ascending=False)
m
# Out:
#                                               count          %
# Zip Code                                     9248.0  24.351581
# School Name                                  9248.0  24.351581
# Mean Scale Score                             9213.0  24.259420
# District Name                                 934.0   2.459383
# Percentage Standard Not Met                    39.0   0.102694
# Area 4 Percentage Below Standard               39.0   0.102694
# Area 4 Percentage Near Standard                39.0   0.102694
# Area 4 Percentage Above Standard               39.0   0.102694
# Area 3 Percentage Below Standard               39.0   0.102694
# Area 3 Percentage Near Standard                39.0   0.102694
# Area 3 Percentage Above Standard               39.0   0.102694
# Area 2 Percentage Below Standard               39.0   0.102694
# Area 2 Percentage Near Standard                39.0   0.102694
# Area 2 Percentage Above Standard               39.0   0.102694
# Area 1 Percentage Below Standard               39.0   0.102694
# Area 1 Percentage Near Standard                39.0   0.102694
# Area 1 Percentage Above Standard               39.0   0.102694
# Percentage Standard Nearly Met                 39.0   0.102694
# Percentage Standard Met and Above              39.0   0.102694
# Percentage Standard Met                        39.0   0.102694
# Percentage Standard Exceeded                   39.0   0.102694
# Test Type                                       0.0   0.000000
# School Code                                     0.0   0.000000
# Test Year_x                                     0.0   0.000000
# County Name                                     0.0   0.000000
# Type ID_y                                       0.0   0.000000
# Test Year_y                                     0.0   0.000000
# Type ID_x                                       0.0   0.000000
# Student Group ID                                0.0   0.000000
# Total Tested with Scores at Reporting Level     0.0   0.000000
# Total Tested at Reporting Level                 0.0   0.000000
# Students with Scores                            0.0   0.000000
# Grade                                           0.0   0.000000
# Test ID                                         0.0   0.000000
# Students Enrolled                               0.0   0.000000
# Students Tested                                 0.0   0.000000
# District Code                                   0.0   0.000000
# County Code                                     0.0   0.000000

# %%
# remove rows with no school Name 

print(len(df))
df.drop(df[df['School Name'].isnull()].index,inplace=True)
print(len(df))
df[df['School Name'].isnull()].index
# Out:
# 37977
# 28729
# Int64Index([], dtype='int64')

# %%
## check nulls 
m = pd.DataFrame([df.isnull().sum(),100*df.isnull().mean()])
m = m.T
m.columns=['count', '%']
m = m.sort_values(by='count',ascending=False)
m.head(10)
# Out:
#                                     count          %
# Mean Scale Score                   7597.0  26.443663
# Area 2 Percentage Below Standard     31.0   0.107905
# Area 2 Percentage Above Standard     31.0   0.107905
# Area 1 Percentage Below Standard     31.0   0.107905
# Area 1 Percentage Near Standard      31.0   0.107905
# Area 3 Percentage Above Standard     31.0   0.107905
# Area 3 Percentage Near Standard      31.0   0.107905
# Percentage Standard Not Met          31.0   0.107905
# Percentage Standard Nearly Met       31.0   0.107905
# Percentage Standard Met and Above    31.0   0.107905

# %%
df[df['Mean Scale Score'].isnull()].sample(5).T
# Out:
#                                                              7152   \
# County Code                                                     15
# District Code                                                63651
# School Code                                                6009773
# Test Year_x                                                   2021
# Student Group ID                                                 1
# Test Type                                                        B
# Total Tested at Reporting Level                                 46
# Total Tested with Scores at Reporting Level                     46
# Grade                                                           13
# Test ID                                                Mathematics
# Students Enrolled                                               47
# Students Tested                                                 46
# Mean Scale Score                                               NaN
# Percentage Standard Exceeded                                 32.61
# Percentage Standard Met                                      32.61
# Percentage Standard Met and Above                            65.22
# Percentage Standard Nearly Met                               23.91
# Percentage Standard Not Met                                  10.87
# Students with Scores                                            46
# Area 1 Percentage Above Standard                             34.78
# Area 1 Percentage Near Standard                              50.00
# Area 1 Percentage Below Standard                             15.22
# Area 2 Percentage Above Standard                             32.61
# Area 2 Percentage Near Standard                              52.17
# Area 2 Percentage Below Standard                             15.22
# Area 3 Percentage Above Standard                             34.78
# Area 3 Percentage Near Standard                              54.35
# Area 3 Percentage Below Standard                             10.87
# Area 4 Percentage Above Standard                              0.00
# Area 4 Percentage Near Standard                               0.00
# Area 4 Percentage Below Standard                              0.00
# Type ID_x                                                        7
# Test Year_y                                                   2021
# Type ID_y                                                        7
# County Name                                                   Kern
# District Name                                McKittrick Elementary
# School Name                                  McKittrick Elementary
# Zip Code                                                   93251.0
#
#                                                                          17697  \
# County Code                                                                 31
# District Code                                                            10314
# School Code                                                            3130259
# Test Year_x                                                               2021
# Student Group ID                                                             1
# Test Type                                                                    B
# Total Tested at Reporting Level                                              9
# Total Tested with Scores at Reporting Level                                  9
# Grade                                                                       13
# Test ID                                                            Mathematics
# Students Enrolled                                                           11
# Students Tested                                                              9
# Mean Scale Score                                                           NaN
# Percentage Standard Exceeded                                                 *
# Percentage Standard Met                                                      *
# Percentage Standard Met and Above                                            *
# Percentage Standard Nearly Met                                               *
# Percentage Standard Not Met                                                  *
# Students with Scores                                                         9
# Area 1 Percentage Above Standard                                             *
# Area 1 Percentage Near Standard                                              *
# Area 1 Percentage Below Standard                                             *
# Area 2 Percentage Above Standard                                             *
# Area 2 Percentage Near Standard                                              *
# Area 2 Percentage Below Standard                                             *
# Area 3 Percentage Above Standard                                             *
# Area 3 Percentage Near Standard                                              *
# Area 3 Percentage Below Standard                                             *
# Area 4 Percentage Above Standard                                             *
# Area 4 Percentage Near Standard                                              *
# Area 4 Percentage Below Standard                                             *
# Type ID_x                                                                    7
# Test Year_y                                                               2021
# Type ID_y                                                                    7
# County Name                                                             Placer
# District Name                                Placer County Office of Education
# School Name                                    Placer County Community Schools
# Zip Code                                                               95603.0
#
#                                                                                4226   \
# County Code                                                                       10
# District Code                                                                  73965
# School Code                                                                  1030386
# Test Year_x                                                                     2021
# Student Group ID                                                                   1
# Test Type                                                                          B
# Total Tested at Reporting Level                                                   26
# Total Tested with Scores at Reporting Level                                       26
# Grade                                                                             13
# Test ID                                               English Language Arts/Literacy
# Students Enrolled                                                                 70
# Students Tested                                                                   26
# Mean Scale Score                                                                 NaN
# Percentage Standard Exceeded                                                    3.85
# Percentage Standard Met                                                        26.92
# Percentage Standard Met and Above                                              30.77
# Percentage Standard Nearly Met                                                 34.62
# Percentage Standard Not Met                                                    34.62
# Students with Scores                                                              26
# Area 1 Percentage Above Standard                                                   *
# Area 1 Percentage Near Standard                                                    *
# Area 1 Percentage Below Standard                                                   *
# Area 2 Percentage Above Standard                                                   *
# Area 2 Percentage Near Standard                                                    *
# Area 2 Percentage Below Standard                                                   *
# Area 3 Percentage Above Standard                                                   *
# Area 3 Percentage Near Standard                                                    *
# Area 3 Percentage Below Standard                                                   *
# Area 4 Percentage Above Standard                                                   *
# Area 4 Percentage Near Standard                                                    *
# Area 4 Percentage Below Standard                                                   *
# Type ID_x                                                                          7
# Test Year_y                                                                     2021
# Type ID_y                                                                          7
# County Name                                                                   Fresno
# District Name                                                        Central Unified
# School Name                                  Central Unified Alternative/Opportunity
# Zip Code                                                                     93722.0
#
#                                                                                  10399  \
# County Code                                                                         19
# District Code                                                                    64725
# School Code                                                                    1964725
# Test Year_x                                                                       2021
# Student Group ID                                                                     1
# Test Type                                                                            B
# Total Tested at Reporting Level                                                     26
# Total Tested with Scores at Reporting Level                                         25
# Grade                                                                               13
# Test ID                                                 English Language Arts/Literacy
# Students Enrolled                                                                   86
# Students Tested                                                                     26
# Mean Scale Score                                                                   NaN
# Percentage Standard Exceeded                                                      8.00
# Percentage Standard Met                                                           8.00
# Percentage Standard Met and Above                                                16.00
# Percentage Standard Nearly Met                                                    4.00
# Percentage Standard Not Met                                                      80.00
# Students with Scores                                                                25
# Area 1 Percentage Above Standard                                                     *
# Area 1 Percentage Near Standard                                                      *
# Area 1 Percentage Below Standard                                                     *
# Area 2 Percentage Above Standard                                                     *
# Area 2 Percentage Near Standard                                                      *
# Area 2 Percentage Below Standard                                                     *
# Area 3 Percentage Above Standard                                                     *
# Area 3 Percentage Near Standard                                                      *
# Area 3 Percentage Below Standard                                                     *
# Area 4 Percentage Above Standard                                                     *
# Area 4 Percentage Near Standard                                                      *
# Area 4 Percentage Below Standard                                                     *
# Type ID_x                                                                            7
# Test Year_y                                                                       2021
# Type ID_y                                                                            7
# County Name                                                                Los Angeles
# District Name                                                       Long Beach Unified
# School Name                                  Long Beach Unified District Level Program
# Zip Code                                                                       90810.0
#
#                                                                       35322
# County Code                                                              54
# District Code                                                         72256
# School Code                                                         5434527
# Test Year_x                                                            2021
# Student Group ID                                                          1
# Test Type                                                                 B
# Total Tested at Reporting Level                                          25
# Total Tested with Scores at Reporting Level                              25
# Grade                                                                    13
# Test ID                                      English Language Arts/Literacy
# Students Enrolled                                                       565
# Students Tested                                                          25
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                          44.00
# Percentage Standard Met                                               44.00
# Percentage Standard Met and Above                                     88.00
# Percentage Standard Nearly Met                                         8.00
# Percentage Standard Not Met                                            4.00
# Students with Scores                                                     25
# Area 1 Percentage Above Standard                                          *
# Area 1 Percentage Near Standard                                           *
# Area 1 Percentage Below Standard                                          *
# Area 2 Percentage Above Standard                                          *
# Area 2 Percentage Near Standard                                           *
# Area 2 Percentage Below Standard                                          *
# Area 3 Percentage Above Standard                                          *
# Area 3 Percentage Near Standard                                           *
# Area 3 Percentage Below Standard                                          *
# Area 4 Percentage Above Standard                                          *
# Area 4 Percentage Near Standard                                           *
# Area 4 Percentage Below Standard                                          *
# Type ID_x                                                                 7
# Test Year_y                                                            2021
# Type ID_y                                                                 7
# County Name                                                          Tulare
# District Name                                               Visalia Unified
# School Name                                                    Redwood High
# Zip Code                                                            93291.0

# %% [markdown]
# # Keep mean scale score even if mean scale score = Nan as other columns still giving data

# %%
# find number of unique entries for each features
unique_values = df.nunique().sort_values()
# select_dtypes(include="number").nunique().sort_values()

# Plot information with y-axis in log-scale
unique_values.plot.bar( figsize=(15, 4), title="Unique values per feature")
plt.show()

# %%
#how many high schools are left? 

df['Grade'].unique()
# Out:
# array([ 6,  7, 11, 13,  3,  4,  5,  8])

# %%
## check nulls 
m = pd.DataFrame([df.isnull().sum(),100*df.isnull().mean()])
m = m.T
m.columns=['count', '%']
m = m.sort_values(by='count',ascending=False)
m.head()
# Out:
#                                    count          %
# Mean Scale Score                  7597.0  26.443663
# Area 2 Percentage Below Standard    31.0   0.107905
# Area 2 Percentage Above Standard    31.0   0.107905
# Area 1 Percentage Below Standard    31.0   0.107905
# Area 1 Percentage Near Standard     31.0   0.107905

# %%
df[df['Area 2 Percentage Below Standard'].isnull()].sample(4).T
# Out:
#                                                                                      3154   \
# County Code                                                                              9
# District Code                                                                        73783
# School Code                                                                         973783
# Test Year_x                                                                           2021
# Student Group ID                                                                         1
# Test Type                                                                                B
# Total Tested at Reporting Level                                                          *
# Total Tested with Scores at Reporting Level                                              0
# Grade                                                                                    6
# Test ID                                                     English Language Arts/Literacy
# Students Enrolled                                                                        *
# Students Tested                                                                          *
# Mean Scale Score                                                                       NaN
# Percentage Standard Exceeded                                                           NaN
# Percentage Standard Met                                                                NaN
# Percentage Standard Met and Above                                                      NaN
# Percentage Standard Nearly Met                                                         NaN
# Percentage Standard Not Met                                                            NaN
# Students with Scores                                                                     0
# Area 1 Percentage Above Standard                                                       NaN
# Area 1 Percentage Near Standard                                                        NaN
# Area 1 Percentage Below Standard                                                       NaN
# Area 2 Percentage Above Standard                                                       NaN
# Area 2 Percentage Near Standard                                                        NaN
# Area 2 Percentage Below Standard                                                       NaN
# Area 3 Percentage Above Standard                                                       NaN
# Area 3 Percentage Near Standard                                                        NaN
# Area 3 Percentage Below Standard                                                       NaN
# Area 4 Percentage Above Standard                                                       NaN
# Area 4 Percentage Near Standard                                                        NaN
# Area 4 Percentage Below Standard                                                       NaN
# Type ID_x                                                                                7
# Test Year_y                                                                           2021
# Type ID_y                                                                                7
# County Name                                                                      El Dorado
# District Name                                                       Black Oak Mine Unified
# School Name                                  Black Oak Mine Unified District Level Program
# Zip Code                                                                           95634.0
#
#                                                           24314  \
# County Code                                                  39
# District Code                                             68585
# School Code                                              122580
# Test Year_x                                                2021
# Student Group ID                                              1
# Test Type                                                     B
# Total Tested at Reporting Level                               7
# Total Tested with Scores at Reporting Level                   6
# Grade                                                         4
# Test ID                                             Mathematics
# Students Enrolled                                            55
# Students Tested                                               *
# Mean Scale Score                                            NaN
# Percentage Standard Exceeded                                NaN
# Percentage Standard Met                                     NaN
# Percentage Standard Met and Above                           NaN
# Percentage Standard Nearly Met                              NaN
# Percentage Standard Not Met                                 NaN
# Students with Scores                                          0
# Area 1 Percentage Above Standard                            NaN
# Area 1 Percentage Near Standard                             NaN
# Area 1 Percentage Below Standard                            NaN
# Area 2 Percentage Above Standard                            NaN
# Area 2 Percentage Near Standard                             NaN
# Area 2 Percentage Below Standard                            NaN
# Area 3 Percentage Above Standard                            NaN
# Area 3 Percentage Near Standard                             NaN
# Area 3 Percentage Below Standard                            NaN
# Area 4 Percentage Above Standard                            NaN
# Area 4 Percentage Near Standard                             NaN
# Area 4 Percentage Below Standard                            NaN
# Type ID_x                                                     9
# Test Year_y                                                2021
# Type ID_y                                                     9
# County Name                                         San Joaquin
# District Name                                Rio Valley Charter
# School Name                                  Rio Valley Charter
# Zip Code                                                95240.0
#
#                                                                           16217  \
# County Code                                                                  29
# District Code                                                             10298
# School Code                                                              116681
# Test Year_x                                                                2021
# Student Group ID                                                              1
# Test Type                                                                     B
# Total Tested at Reporting Level                                               *
# Total Tested with Scores at Reporting Level                                   *
# Grade                                                                         7
# Test ID                                          English Language Arts/Literacy
# Students Enrolled                                                             *
# Students Tested                                                               *
# Mean Scale Score                                                            NaN
# Percentage Standard Exceeded                                                NaN
# Percentage Standard Met                                                     NaN
# Percentage Standard Met and Above                                           NaN
# Percentage Standard Nearly Met                                              NaN
# Percentage Standard Not Met                                                 NaN
# Students with Scores                                                          0
# Area 1 Percentage Above Standard                                            NaN
# Area 1 Percentage Near Standard                                             NaN
# Area 1 Percentage Below Standard                                            NaN
# Area 2 Percentage Above Standard                                            NaN
# Area 2 Percentage Near Standard                                             NaN
# Area 2 Percentage Below Standard                                            NaN
# Area 3 Percentage Above Standard                                            NaN
# Area 3 Percentage Near Standard                                             NaN
# Area 3 Percentage Below Standard                                            NaN
# Area 4 Percentage Above Standard                                            NaN
# Area 4 Percentage Near Standard                                             NaN
# Area 4 Percentage Below Standard                                            NaN
# Type ID_x                                                                     7
# Test Year_y                                                                2021
# Type ID_y                                                                     7
# County Name                                                              Nevada
# District Name                                 Nevada County Office of Education
# School Name                                  Earle Jamieson Educational Options
# Zip Code                                                                95959.0
#
#                                                                 24813
# County Code                                                        39
# District Code                                                   68627
# School Code                                                    129916
# Test Year_x                                                      2021
# Student Group ID                                                    1
# Test Type                                                           B
# Total Tested at Reporting Level                                     5
# Total Tested with Scores at Reporting Level                         *
# Grade                                                               4
# Test ID                                                   Mathematics
# Students Enrolled                                                  57
# Students Tested                                                     *
# Mean Scale Score                                                  NaN
# Percentage Standard Exceeded                                      NaN
# Percentage Standard Met                                           NaN
# Percentage Standard Met and Above                                 NaN
# Percentage Standard Nearly Met                                    NaN
# Percentage Standard Not Met                                       NaN
# Students with Scores                                                0
# Area 1 Percentage Above Standard                                  NaN
# Area 1 Percentage Near Standard                                   NaN
# Area 1 Percentage Below Standard                                  NaN
# Area 2 Percentage Above Standard                                  NaN
# Area 2 Percentage Near Standard                                   NaN
# Area 2 Percentage Below Standard                                  NaN
# Area 3 Percentage Above Standard                                  NaN
# Area 3 Percentage Near Standard                                   NaN
# Area 3 Percentage Below Standard                                  NaN
# Area 4 Percentage Above Standard                                  NaN
# Area 4 Percentage Near Standard                                   NaN
# Area 4 Percentage Below Standard                                  NaN
# Type ID_x                                                           9
# Test Year_y                                                      2021
# Type ID_y                                                           9
# County Name                                               San Joaquin
# District Name                                Valley View Charter Prep
# School Name                                  Valley View Charter Prep
# Zip Code                                                      95304.0

# %%
df.drop(df[df['Area 2 Percentage Below Standard'].isnull()].index,inplace=True)
m = pd.DataFrame([df.isnull().sum(),100*df.isnull().mean()])
m = m.T
m.columns=['count', '%']
m = m.sort_values(by='count',ascending=False)
m.head()
# Out:
#                                    count          %
# Mean Scale Score                  7566.0  26.364207
# County Code                          0.0   0.000000
# Area 4 Percentage Above Standard     0.0   0.000000
# Area 2 Percentage Above Standard     0.0   0.000000
# Area 2 Percentage Near Standard      0.0   0.000000

# %%
df.shape
# Out:
# (28698, 38)

# %%
for col in df.select_dtypes('object'):
    print(col)
    df[col] = df[col].str.replace('*','')
# Out:
# Test Type
# Total Tested at Reporting Level
# Total Tested with Scores at Reporting Level
# Students Enrolled
# Students Tested
# Mean Scale Score
# Percentage Standard Exceeded
# Percentage Standard Met
# Percentage Standard Met and Above
# Percentage Standard Nearly Met
# Percentage Standard Not Met
# <ipython-input-141-41532e5d85de>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df[col] = df[col].str.replace('*','')
# Students with Scores
# Area 1 Percentage Above Standard
# Area 1 Percentage Near Standard
# Area 1 Percentage Below Standard
# Area 2 Percentage Above Standard
# Area 2 Percentage Near Standard
# Area 2 Percentage Below Standard
# Area 3 Percentage Above Standard
# Area 3 Percentage Near Standard
# Area 3 Percentage Below Standard
# Area 4 Percentage Above Standard
# Area 4 Percentage Near Standard
# Area 4 Percentage Below Standard
# County Name
# District Name
# School Name

# %%
cols = df.columns[df.dtypes.eq('object')]

convert = cols[:-3]

# %%
df[convert] = df[convert].apply(pd.to_numeric,errors='coerce')

# %%
df.drop('Test Type' ,inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28698 entries, 36 to 37976
# Data columns (total 37 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   County Code                                  28698 non-null  int64
#  1   District Code                                28698 non-null  int64
#  2   School Code                                  28698 non-null  int64
#  3   Test Year_x                                  28698 non-null  int64
#  4   Student Group ID                             28698 non-null  int64
#  5   Total Tested at Reporting Level              27490 non-null  float64
#  6   Total Tested with Scores at Reporting Level  27473 non-null  float64
#  7   Grade                                        28698 non-null  int64
#  8   Test ID                                      0 non-null      float64
#  9   Students Enrolled                            27037 non-null  float64
#  10  Students Tested                              25806 non-null  float64
#  11  Mean Scale Score                             16468 non-null  float64
#  12  Percentage Standard Exceeded                 22939 non-null  float64
#  13  Percentage Standard Met                      22939 non-null  float64
#  14  Percentage Standard Met and Above            22939 non-null  float64
#  15  Percentage Standard Nearly Met               22939 non-null  float64
#  16  Percentage Standard Not Met                  22939 non-null  float64
#  17  Students with Scores                         25787 non-null  float64
#  18  Area 1 Percentage Above Standard             18571 non-null  float64
#  19  Area 1 Percentage Near Standard              18571 non-null  float64
#  20  Area 1 Percentage Below Standard             18571 non-null  float64
#  21  Area 2 Percentage Above Standard             18571 non-null  float64
#  22  Area 2 Percentage Near Standard              18571 non-null  float64
#  23  Area 2 Percentage Below Standard             18571 non-null  float64
#  24  Area 3 Percentage Above Standard             18571 non-null  float64
#  25  Area 3 Percentage Near Standard              18571 non-null  float64
#  26  Area 3 Percentage Below Standard             18571 non-null  float64
#  27  Area 4 Percentage Above Standard             18571 non-null  float64
#  28  Area 4 Percentage Near Standard              18571 non-null  float64
#  29  Area 4 Percentage Below Standard             18571 non-null  float64
#  30  Type ID_x                                    28698 non-null  int64
#  31  Test Year_y                                  28698 non-null  int64
#  32  Type ID_y                                    28698 non-null  int64
#  33  County Name                                  28698 non-null  object
#  34  District Name                                28698 non-null  object
#  35  School Name                                  28698 non-null  object
#  36  Zip Code                                     28698 non-null  float64
# dtypes: float64(25), int64(9), object(3)
# memory usage: 8.3+ MB

# %%
df.sample(4).T
# Out:
#                                                                             2587   \
# County Code                                                                     8
# District Code                                                               10082
# School Code                                                                830059
# Test Year_x                                                                  2021
# Student Group ID                                                                1
# Total Tested at Reporting Level                                               NaN
# Total Tested with Scores at Reporting Level                                   NaN
# Grade                                                                          11
# Test ID                                                                       NaN
# Students Enrolled                                                            46.0
# Students Tested                                                               NaN
# Mean Scale Score                                                              NaN
# Percentage Standard Exceeded                                                  NaN
# Percentage Standard Met                                                       NaN
# Percentage Standard Met and Above                                             NaN
# Percentage Standard Nearly Met                                                NaN
# Percentage Standard Not Met                                                   NaN
# Students with Scores                                                          NaN
# Area 1 Percentage Above Standard                                              NaN
# Area 1 Percentage Near Standard                                               NaN
# Area 1 Percentage Below Standard                                              NaN
# Area 2 Percentage Above Standard                                              NaN
# Area 2 Percentage Near Standard                                               NaN
# Area 2 Percentage Below Standard                                              NaN
# Area 3 Percentage Above Standard                                              NaN
# Area 3 Percentage Near Standard                                               NaN
# Area 3 Percentage Below Standard                                              NaN
# Area 4 Percentage Above Standard                                              NaN
# Area 4 Percentage Near Standard                                               NaN
# Area 4 Percentage Below Standard                                              NaN
# Type ID_x                                                                      10
# Test Year_y                                                                  2021
# Type ID_y                                                                      10
# County Name                                                             Del Norte
# District Name                                Del Norte County Office of Education
# School Name                                                           Castle Rock
# Zip Code                                                                  95531.0
#
#                                                                   14238  \
# County Code                                                          21
# District Code                                                     65458
# School Code                                                     6024772
# Test Year_x                                                        2021
# Student Group ID                                                      1
# Total Tested at Reporting Level                                   400.0
# Total Tested with Scores at Reporting Level                       400.0
# Grade                                                                 5
# Test ID                                                             NaN
# Students Enrolled                                                  61.0
# Students Tested                                                    61.0
# Mean Scale Score                                                 2453.6
# Percentage Standard Exceeded                                      11.48
# Percentage Standard Met                                           11.48
# Percentage Standard Met and Above                                 22.95
# Percentage Standard Nearly Met                                    26.23
# Percentage Standard Not Met                                       50.82
# Students with Scores                                               61.0
# Area 1 Percentage Above Standard                                  11.48
# Area 1 Percentage Near Standard                                   42.62
# Area 1 Percentage Below Standard                                   45.9
# Area 2 Percentage Above Standard                                   6.56
# Area 2 Percentage Near Standard                                    45.9
# Area 2 Percentage Below Standard                                  47.54
# Area 3 Percentage Above Standard                                    8.2
# Area 3 Percentage Near Standard                                    54.1
# Area 3 Percentage Below Standard                                   37.7
# Area 4 Percentage Above Standard                                    0.0
# Area 4 Percentage Near Standard                                     0.0
# Area 4 Percentage Below Standard                                    0.0
# Type ID_x                                                             7
# Test Year_y                                                        2021
# Type ID_y                                                             7
# County Name                                                       Marin
# District Name                                San Rafael City Elementary
# School Name                                          Venetia Valley K-8
# Zip Code                                                        94903.0
#
#                                                                       28946  \
# County Code                                                              45
# District Code                                                         10454
# School Code                                                          129957
# Test Year_x                                                            2021
# Student Group ID                                                          1
# Total Tested at Reporting Level                                        84.0
# Total Tested with Scores at Reporting Level                            84.0
# Grade                                                                     4
# Test ID                                                                 NaN
# Students Enrolled                                                      11.0
# Students Tested                                                        10.0
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                            NaN
# Percentage Standard Met                                                 NaN
# Percentage Standard Met and Above                                       NaN
# Percentage Standard Nearly Met                                          NaN
# Percentage Standard Not Met                                             NaN
# Students with Scores                                                   10.0
# Area 1 Percentage Above Standard                                        NaN
# Area 1 Percentage Near Standard                                         NaN
# Area 1 Percentage Below Standard                                        NaN
# Area 2 Percentage Above Standard                                        NaN
# Area 2 Percentage Near Standard                                         NaN
# Area 2 Percentage Below Standard                                        NaN
# Area 3 Percentage Above Standard                                        NaN
# Area 3 Percentage Near Standard                                         NaN
# Area 3 Percentage Below Standard                                        NaN
# Area 4 Percentage Above Standard                                        NaN
# Area 4 Percentage Near Standard                                         NaN
# Area 4 Percentage Below Standard                                        NaN
# Type ID_x                                                                 9
# Test Year_y                                                            2021
# Type ID_y                                                                 9
# County Name                                                          Shasta
# District Name                                Northern Summit Academy Shasta
# School Name                                  Northern Summit Academy Shasta
# Zip Code                                                            96007.0
#
#                                                                 27729
# County Code                                                        43
# District Code                                                   69419
# School Code                                                   6047112
# Test Year_x                                                      2021
# Student Group ID                                                    1
# Total Tested at Reporting Level                                 348.0
# Total Tested with Scores at Reporting Level                     348.0
# Grade                                                               5
# Test ID                                                           NaN
# Students Enrolled                                               117.0
# Students Tested                                                 116.0
# Mean Scale Score                                               2625.0
# Percentage Standard Exceeded                                     75.0
# Percentage Standard Met                                         24.14
# Percentage Standard Met and Above                               99.14
# Percentage Standard Nearly Met                                   0.86
# Percentage Standard Not Met                                       0.0
# Students with Scores                                            116.0
# Area 1 Percentage Above Standard                                55.17
# Area 1 Percentage Near Standard                                 44.83
# Area 1 Percentage Below Standard                                  0.0
# Area 2 Percentage Above Standard                                60.34
# Area 2 Percentage Near Standard                                 38.79
# Area 2 Percentage Below Standard                                 0.86
# Area 3 Percentage Above Standard                                32.76
# Area 3 Percentage Near Standard                                 66.38
# Area 3 Percentage Below Standard                                 0.86
# Area 4 Percentage Above Standard                                50.86
# Area 4 Percentage Near Standard                                 48.28
# Area 4 Percentage Below Standard                                 0.86
# Type ID_x                                                           7
# Test Year_y                                                      2021
# Type ID_y                                                           7
# County Name                                               Santa Clara
# District Name                                         Cupertino Union
# School Name                                  William Faria Elementary
# Zip Code                                                      95014.0

# %%
dist_nums = df['County Name'].value_counts()
plt.hist(dist_nums,bins=30)
plt.show()

# %%
## per county reporting school count

# %%
df['County Name'].value_counts()
# Out:
# Los Angeles        4072
# San Diego          1628
# San Joaquin        1366
# Santa Clara        1224
# Ventura            1085
# Stanislaus         1080
# Fresno             1059
# San Mateo          1015
# Tulare             1000
# Orange              885
# Shasta              869
# Sacramento          862
# San Bernardino      828
# Riverside           694
# Kern                694
# Alameda             638
# Placer              634
# Contra Costa        600
# Humboldt            583
# Marin               515
# Sonoma              478
# Butte               437
# Kings               418
# El Dorado           382
# Siskiyou            360
# Merced              346
# Tehama              344
# Yuba                300
# Sutter              271
# Lake                269
# Madera              248
# San Luis Obispo     246
# Mendocino           236
# Nevada              235
# Imperial            224
# Tuolumne            215
# Santa Barbara       214
# Glenn               201
# Lassen              196
# Monterey            174
# Trinity             164
# San Francisco       160
# Calaveras           138
# Inyo                120
# Solano              118
# San Benito          118
# Yolo                118
# Mariposa            116
# Amador               94
# Santa Cruz           90
# Modoc                76
# Mono                 66
# Plumas               56
# Colusa               47
# Del Norte            36
# Napa                 24
# Alpine               24
# Sierra                8
# Name: County Name, dtype: int64

# %%
dabl.plot(df, target_col = 'Percentage Standard Exceeded')
plt.show()
# Out:
# Target looks like regression
# Showing only top 10 of 26 continuous features
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/supervised.py:58: UserWarning: Missing values in target_col have been removed for regression
#   warn("Missing values in target_col have been removed for regression",
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:632: UserWarning: Dropped 2 outliers in column Area 3 Percentage Above Standard.
#   warn("Dropped {} outliers in column {}.".format(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:632: UserWarning: Dropped 1 outliers in column Area 4 Percentage Above Standard.
#   warn("Dropped {} outliers in column {}.".format(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/supervised.py:130: UserWarning: Missing values in target_col have been removed for regression
#   warn("Missing values in target_col have been removed for regression",
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# /Users/robertrustia/opt/anaconda3/lib/python3.8/site-packages/dabl/plot/utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(

# %%
df['Students with Scores'].nunique()
# Out:
# 835

# %%
df['Percentage Standard Exceeded'].nunique()
# Out:
# 3960

# %%
df.to_csv('../data/cleaned_labeled_2021-SB_math_ela_scores.csv')

# %%
score_means = df.groupby('County Name')[['Percentage Standard Met','Percentage Standard Exceeded']].mean()
score_means.head(10)
# Out:
#               Percentage Standard Met  Percentage Standard Exceeded
# County Name
# Alameda                     24.326453                     26.593962
# Alpine                      20.000000                     24.285000
# Amador                      20.012143                     10.384286
# Butte                       24.952086                     13.005464
# Calaveras                   19.639794                     10.412577
# Colusa                      20.291071                      8.622500
# Contra Costa                22.366193                     20.539408
# Del Norte                   22.212727                     13.475000
# El Dorado                   26.573872                     21.241992
# Fresno                      17.666024                      8.671681
